# %%
cd /content/drive/MyDrive/erlangshen
# Out:
# /content/drive/MyDrive/erlangshen

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 7.9 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 36.9 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 51.3 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 44.2 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=7d31a77c94de6b276a1da6d67493fce0e522e385b66770d3f79484ee3fe7156f
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.53 tokenizers-0.12.1 transformers-4.18.0

# %%
from transformers import BertForSequenceClassification
from transformers import BertTokenizer
import torch
from tqdm import tqdm
import csv
import sys
import os

# %%
tokenizer=BertTokenizer.from_pretrained('IDEA-CCNL/Erlangshen-Roberta-330M-Similarity')
model=BertForSequenceClassification.from_pretrained('IDEA-CCNL/Erlangshen-Roberta-330M-Similarity')

# %%
texta='今天的饭不好吃'
textb='今天心情不好'

output=model(torch.tensor([tokenizer.encode(texta,textb)]))
torch.nn.functional.softmax(output.logits,dim=-1)[0][0]
# 左：不相似概率
# 右：相似概率
# Out:
# tensor(0.9999, grad_fn=<SelectBackward0>)

# %%
# corpus_path = ["data/bq_corpus/test.tsv", "data/lcqmc/test.tsv", "data/paws-x-zh/test.tsv"]
# for path in corpus_path:
#     cls_result = []
#     test_pairs = open(path, encoding='utf-8').readlines()    
#     # sentence_list_1 = []
#     # sentence_list_2 = []
#     # for pair in test_pairs:
#     #     # print(pair.split('\t'))
#     #     sentence_list_1.append(pair.split('\t')[0])
#     #     sentence_list_2.append(pair.split('\t')[1])
#     # print(sentence_list_1)
#     # print(sentence_list_2)

#     for i in tqdm(range(len(test_pairs))):
#         pair = test_pairs[i].split()

#         output=model(torch.tensor([tokenizer.encode(pair[0],pair[1])]))
#         if torch.nn.functional.softmax(output.logits,dim=-1)[0][0] > 0.5:
#             cls_result.append(1)
#         else:
#             cls_result.append(0)
#         # print(torch.nn.functional.softmax(output.logits,dim=-1)[0][0])
              
#     with open('result/' + path.split('/')[1] + '.tsv', 'w') as out_file:
#         tsv_writer = csv.writer(out_file, delimiter='\t')
#         tsv_writer.writerow(['index', 'prediction'])
#         for i in range(len(cls_result)):
#             tsv_writer.writerow([str(i), str(cls_result[i])])
# Out:
# ['为什么我无法看到额度', '为啥换不了', '借了钱，但还没有通过，可以取消吗？', '为什么我申请额度输入密码就一直是那个页面', '今天借明天还款可以？', '你好！今下午咱没有扣我款？', '所借的钱是否可以提现？', '不是邀请的客人就不能借款吗', '人脸失别不了，开不了户', '一天利息好多钱', '为啥还没开放啊', '开通.微粒贷', '咋么才能收到邀请', '扣款时间是几点', '为什么借款总是不通过', '为什么我的无法查看额度', '请问月息多少', '借钱可好取现', '可以开结清证明吗？', '你好，我银行卡被法院封了，能否换我儿子的卡还款', '一般是什么时候自动扣款？', '我想问什么时候会再打电话过来呢？', '请问有这个手机端的app吗', '开不了户', '不满足微众银行条件', '那我刚刚申请的贷款。。取消掉怎么操作', '什么时候发出邀请呢', '为什么提前还清所有借款不能再借呢？', '我换手机号了', '为什么刚刚借钱要输入很多次验证码和支付密码是不是我手机问题还款就可以', '不借了不要打来了', '需要提供什么借款材料', '不小心挂断', '怎么关掉这个', 'QQ里的微粒贷怎么找不到了', '13号扣款，今天怎么没有扣', '亲，中奖的要怎样留地址呢？', '为什么j借款未通过', 'QQ钱包没有入口是不是没绑定银行卡', '咋么开通', '如何更改手机号', '为什么会申请失败？', '如何解绑银行卡', '怎么降低借款额度', '您好请把借款功能关闭', '借款时，银行验证电话没接到', '借钱了怎么还啊', '你好，我绑定的银行卡掉了，能换过一张银行卡绑定吗', '手机号换了，怎么更改', '如何提高借款额度', '我为什么木有额度', '我可以主动给银行打电话来确认吗', '如何解除', '0开通', '可以注销微众银行已经开户的了？', '为什么我卡有足够钱，但还款失败？', '上面提示我未满足借贷条件', '多笔借贷利息', '、怎么提额', '审核需要多长时间？', '如果获得权限', '未满足银行审批', 'QQ上也显示借款失败', '手机号换了，怎么更改', '关闭微粒货', '为什么我借的钱还没到账？', '是不是苹果机子显示不了', '为满足微众银行审批要求是什么意思', '微粒贷借钱页面显示未满足微众银行审批', '刚才我输错了身份验证，结果就这样了', '说身份证号码多次输错无法借款', 'qq里面没有微粒米怎么办', '我有那些未满足银行审批', '名额没有', '怎么才能算是邀请朋友', '为什么我在手机上打不开微粒贷', '刚刚不小心挂掉了你们打过来的电话了', '未满足于微众银行审批', '迟还款几天会影响信用', '为什么电话审核不通过', '不符合借款要求', '显示我身份输入错误多，无法借款', '借款可以借几次', '他说我身份信息输入错误次数过多怎么弄', '如何获得微粒贷', '你好微粒贷申请需要那些资料的了。', '能不能帮我查一下我这个月的账单是多少', '有电话我没接到没事吧', '为什么评估未通过', '没有通过怎么办', '申请延期一天还款', '10000若分5个月，1个月还完怎么计息', '你好，我还款帐变更要如何更改', '借款后银行没来电话怎么取消', '刚才没接到电话，回拔不成功', '晚一天还款会逾期吗', '如果逾期了，利益怎么算', '在没', '本期还款记录', '我是为了这个评分的', '为什么有也查看不了额度', '还款证明', '为什么没有打电话来呢？', '怎么现在不能还款', '是不是欠款全部还进去，马上就可以贷出来', '怎么我没微粒贷', '为什么我微信没有微粒贷借款', '还款以后不能借了，什么情况', '苹果手机能开通吗', '定期存款产品', '要怎么才能符合审批', '利息怎么计算', '欠款一次性还清', '威力带开通方法', '几号还款', '发账单到我QQ', '微粒代怎么算息', '支持哪些银行还款', '你好！为什么还款成功后，没有恢复额度', '借款到还款期限', '你好我要跟换绑定银行卡', '为什么额度没有恢复呢', '如何贷款？', '可以申请推迟还款吗', '你好我怎么总是还款失败', '为什么不能直接绑定微信支付？？', 'iPhone7抢购太假了', '未满足银行审核要求', '借贷钱不可以用于什么？', '为什么我的借款一直没有消息', '什么时候能借', '你好！我想申请借款，但页面显示说“综合评估未通过”，请问是什么原因？', '你好我想知道借钱之后利息怎么算', '未满足微众银行要求是什么意思', '想还款，总是不能打开', '如何对口银行还款？', '分期这期账单', '为什么每次贷款都要收取费用', '为什么我qq上的微粒贷有额度，借款却显示综合评估未通过？', '查看不到我可贷额度', '点解我用工商还不到钱', '为什么不可以手动还款', '为啥我微信没这个微粒贷借钱应用呢', '微众银行，每天转出有限额吗？', '转账出去是否收费', '为满足审批要求，是什么意思', '你好一直显示身份证输入错误怎么办', '不可以提现吗', '多次借款', '什么时候开始还款？', '我要借款', '我什么时候可以进入微粒贷借款', '四天了，为什么还没有电话确认', '借款之后是否可以提现资金还是只可以用来买东西', '如何一次还清', '你们电话多少啊', '为什么我卡有足够钱，但还款失败？', '1:看不到微粒', "'请问晚一天还款可以", '一次性还清马上就可以在贷吗？', '支持农行吗', '更换扣款卡', '10万额度每月需要还多少', '众享华通安全吗', '我为什么借钱失败', '错过了接电话怎么办', '显示我身份输入错误多，无法借款', '下载上了，就是不会用啊', '我的啥时候可以借', '20000多少利息', '我今天还款', '你这电话是多少', '现在能不能贷款', '如何领取优惠券', '开通额度借钱', '微粒贷借款利息多高', 'QQ钱包怎么没有？', '13借的，沒有自动扣款', '提醒身份证信息输入错误多次', '我没有通过审批是什么意思', '还款日是什么时候', '为什么会提示输入身份信息次数过多', '如何提前还清借贷', '微信个人信息和借记卡都正常，为什么总是借款失败', '借款是不是随时可以一次性还清，有没有其它费用', '开通条件', '账单日是哪一天？', ':为什么没有微粒贷何时会邀请我使用微粒贷如何获得微粒贷借款资格', '10月6的今天扣了吗', '求开通微粒贷，马上本科毕业了，需要租', '5分钟内没下来就不要了', '要还本次账单', '强制开通', '2十几分钟了都没有消息！还说三分钟搞定？？？', '取消微粒贷的借钱', '为什么提前还款却是还款失败卡里也有钱', '可以提前还款吗', '一次性还完借款可以马上借钱吗', '为什么我凌晨没有扣款', '申请几时能办下来', '怎么我看不到微粒贷的入口？', '你好！为什么还款成功后，没有恢复额度', '为什么说我的综合评估不过？', '何时可以享受微粒贷', '你好，审核电话怎么还不打？', '昨晚电话没接到何时还会再联系', '()っ看不到', '我可以用微信零钱还吗？', '什么情况导致评估不过？', '你们的服务热线', '下一次什么时候还款', '7000我一天還多少錢', '取现借款', '借了但银行没打电来来', '钱包里面微粒在哪里，找不见尼', '微粒贷这样回复我。我在微信找不到', '你好。我可以在微粒贷贷款嘛。', '没有解决，手机号码是正确的，就是收不到验证码是什么问题', '为何评估未能通过', '为什么在验证码输入后点确认就会返回额度页面', '上面显示！未满足银行审批要求', '如何更改还款周期', '关注了没找到呢', '我绑定的银行卡折了，换了张卡，卡号变了', '如何更改联系电话', '齐鲁稳固有个21天的理财，最少五万起，21天后收益应该是多少，？4.00%的效益', '我需要修改电话号码', '我昨晚申请的，现在钱没到，也没有人联系我', '为什么资金理财里面没有微粒贷？', '你好，请问可以开贷款结清证明吗？', '提前还还能借吗', '申请借贷多久到账', '卡里有钱了，可以扣款了吗', '己邦定己开户。而APP止没有?', '如何才会有微粒贷的图标', '你好！有没有客服电话号码？', '从我银行卡上自动扣除的，第一期老是还款失败，为什么啊？', '不行现在就邀请', '问下您的公司名称', '借款后多久会打电话联系', '我想提升额度', '怎么取消借贷啊', '银行需要结清证明', '3#没有实际的解决问题', '微众可以办理信用卡吗', '借款怎么说身份信息输入错误多，我没输入错误啊？', '要变更电话号码怎么更改', '如还完，可以继续贷吗', '一万元一天利息50元是吧？', '你好，可以出一个上期结清证明给我吗？', '怎样才能更正身份证号码', '6刚刚手机没电了', '光大银行信用卡', '你好，请问可以开贷款结清证明吗？', '开通教程', '为什么我借款的时候填写资料之后提示我身份信息输入错误过多', '都支持那家银行', '/:|-)怎么没图标', '怎么看额度', '0开通', '为什么有的人没有额度', '怎么才能出额度', '提前还清欠额，能再次贷款么', '现在买没有收益啊！得到 ...
# ['为什么开通了却没有额度\n', '为两次还都提示失败呢\n', '可否取消\n', '为什么要输入支付密码来验证\n', '今天借明天还要手续费吗\n', '你好今天怎么没有扣款呢\n', '该笔借款可以提现吗！\n', '一般什么样得人会受邀请\n', '我输入的资料都是正确的，为什么总说不符开户失败？\n', '1万利息一天是5元是吗\n', '不是微粒贷客户，怎么可以受邀\n', '帮我开通\n', '为什么我6号扣还款的到现在还没\n', '无利息的还款时间是多久？\n', '为什么审请不通过\n', '为什么我点进去没有额度呢\n', '2万块月息是多少\n', '可以提现金？\n', '还清钱后能继续借吗？\n', '换卡什么时候能换好\n', '一般几点扣款\n', '那什么时候打来电话？\n', '手机信号不好\n', '人脸失别不了，开不了户\n', '“您未满足微众银行审批要求，无法查看额度”，这是为什么？什么原因呢\n', '刚刚申请了贷款，可以取消吗？\n', '借款没打电话\n', '提前还款利息怎么算\n', '如果我换手机怎么办？\n', '借款连续输验证码和密码\n', '不想借钱了，但是不小心按到借钱按钮了\n', '是不是苹果手机都没开通啊\n', '不好意思，刚刚有事没有接听您的电话，现在可以打过来了，谢谢！\n', '如何退出微利贷\n', '图标在哪儿\n', '您好，今天我没有扣款，你查查\n', '要怎样充值？\n', '我为什么借不起来\n', 'qq微粒贷和微信微粒贷有什么不一样\n', '可以申请吗没有微粒贷帐号\n', '如何更改绑定的手机号码？\n', '但是审核不通过\n', '如果解除银行卡绑定\n', '额度降低了\n', '不要就说这个\n', '没接到电话确认！什么时候在打\n', '18号还款日可以不凌晨扣款，我18日下午还款可以吗\n', '绑定的银行卡丢了怎么办换卡换扣款卡\n', '我的手机号码换了怎么换？\n', '0.05/是多\n', '为什么我有朋友在这里没有额度？\n', '申请多少额度需要电话确认\n', '怎么样才能把微粒贷删掉\n', '开通、借款\n', '不要\n', '为什么帐户有钱，我提前还款，却显示还款失败！\n', '不符合微银行的条件\n', '4:怎么计息\n', '开通怎么开道\n', '借款需要多长时间审核\n', '我要进入w贷\n', '如何满足审批要求\n', '上面我能借2千5。现在借了5百，还有2千借不出来了？为什么？\n', '怎样更改电话号码\n', '没收到信息\n', '一般多长时间到账\n', '必须是智能手机？\n', '为什么我不能用\n', '农业银行\n', '你好我想借款昨天输入密码错误但是今天一直显示我密码输入错误次数过多要第二天尝试\n', '我已经把真确的身份证号码输进去了，为什么不可以借贷呀\n', '但是QQ没有\n', '未满足审批\n', '可以邀请我不？给我个名额\n', '不是邀請的、要怎么样开通\n', '为什么别人手机有\n', '错过审核电话\n', '未满足申请要求是什么\n', '电话确认需要多久？\n', '刚刚审核了，怎么未通过？\n', '不满足审核\n', '我借款不成功怎么个情况？\n', '一人可以借几次？\n', '为什么补充信息弄不了\n', '借了款，没显示\n', '你好，我手机上怎么显示微粒贷还没有开通\n', '借个月分期还账单\n', '刚审核电话没有接到\n', '为什么有了微粒贷界面审核不通过\n', '为什么我不满足微众银行的审批标准？标准是什么呢\n', '逾期1天会记入个人征信吗？\n', '7天内不计息，怎解？\n', '怎么更改分期还款\n', '不用提醒了我不借了\n', '没接到电话确认！什么时候在打\n', '逾期一天了，我该怎么还？\n', '如果借了1000元逾期十天\n', '到现在也没到账啊\n', '我还款记录可以\n', '说评分不足\n', '妈的，为什么我没有额度\n', '还款记录可以打印凭证吗\n', '提交了借贷多少时间内打电话确认\n', '现在因为资金问题无法及时还款\n', '如果提前还清可以再借么\n', '怎么qq钱包里没微粒贷\n', '你好我的微信怎么没有微粒贷款\n', '现在为何不能还钱?\n', '申请后，需要电话确认，需要那些资料吗\n', '定期存款额度\n', '审批不足应该怎么办\n', '你好，这个怎么算利息？能贷多少？\n', '能还一期，然后全部还清吗
河之一。', '他在 2009 年搬回了费城，现在住在纽约市。', '1954 年 6 月 30 日，他因胃癌于俄克拉荷马州克莱摩尔病逝，而林恩·瑞格斯纪念馆则位于纽约市。', '什蒂普西奇出生于德国科恩堡，在维也纳斯塔莫斯多夫度过了他的童年。', '凯塔王朝从 12 世纪至 17 世纪初一直统治着前帝国及帝国时期的马里。', '“天使之眼”是 1946 年的一首流行歌曲，由马特·丹尼斯作曲，厄尔·布伦特作词。', '作曲人是茜娅姆，作词人是 Sreekumaran Thampi 和 Sathyan Anthikkad。', '该影片在商业上取得巨大成功，也是塞尔乔·索利马较为成功的电影之一，且政治元素比该导演之前的意大利式西部片要少。', '迦比尔要求莎莉卡揭露其终止兰威尔比赛的计划。', '团队回应了 2 月 19 日同一个晚上的下一场比赛的变化。', '中卫约翰·盖奇在 1805 年 5 月为北海使用了它们，中尉罗伯特·拉姆齐在 1806 年取代了他。', '艾玛·汤森德由 DGA Associates 的大卫·戈德温代表。', '纳舒厄白银骑士队属于夏季大学联盟，目前是该市的球队。', '从大桥的西端开始，宾夕法尼亚州 268 号公路往南延伸至帕克，往北与埃姆伦顿相接。', '这些在英国十分常见，但在欧洲其他地方相对少见，至少对于大型铁路机车来说是如此。', '阿尔斯通于 1965 年 12 月 21 日出生在马里兰州奥克森山。他就读于康涅狄格州纽黑文市的奥克森山高中。', '美国总伤亡人数为 28 人，而越共的损失为 345 人死亡，另有 192 人估计死亡。', '在 CA，特许会计师的头衔（斯里兰卡斯里兰卡）只能由斯里兰卡会计师学会的成员使用。', '在于 3 月 14 日收购了 E-Plus 剩余的股份后，Simyo 属于荷兰电信集团 KPN。', '除凯肯德尔外，罗伯特·怀特和约书亚·苏尔·齐默尔曼也担任了汉普夏县的档案馆专员。', '新教派、清教派和福音派的运动兴起期间经常有人表达这种观点。', '费耶诺德鹿特丹队以 4 : 2 击败托特纳姆热刺足球俱乐部，从而赢得了 1973-74 欧洲联盟杯。', '塔尔福尔德·伊利是克拉布·罗宾逊早期好友约翰·陶威尔·拉特的孙子。', '他的父亲在他年少时就去世了，他的母亲塞缪尔·亚当斯于 1842 年嫁给凯瑟琳·A·费根，后者两年后成为阿肯色州州长。', '他们还发行了专辑《Vices》的第 2 首歌曲，作为 6 月 13 日发行的专辑第五首单曲。', '悉尼水务局于 1888 年从市议会手上接管了悉尼的供水。', '蔡讽还有一个儿子，叫蔡瑁。', 'NS', '这扩大了马萨诸塞州和罗德岛省之间的冲突地区。', '斯劳高中是伯克郡的一所精英女子语法学校，现在位于白金汉郡的斯劳。', '它邻近 Lough Corrib，位于康尼马拉的通往 Oughterard 和 Clifden 的 N59 公路。', '虽然排除黑人球员并非一项书面规定，但自 1933 年以来还没有非裔美国人曾为国家橄榄球联盟效力。', '在阿里死后，穆阿维耶上台执政，建立了一个王朝。', '1994 年，Rodrigo Leão 离开乐队开始单飞生涯，被卡洛斯·玛丽亚·特林达德（键盘合成手）所取代。', '1933 年，卡特尔写道，在所有的北欧人种中，“欧洲人种的智力发育水平最高，性情最为稳定”。', '亚高
恩、米尔福德米尔和巴尔的摩县。', '他由约翰·委拉斯开兹训练，在他最重要的比赛中，他的骑师是乔基·戴尔·罗曼斯。', '查尔斯·塞莱斯汀在萨瓦纳的时候，从一家报纸上了解到他的儿子谢尔曼在萨凡纳运动期间去世，将军从来没有见过这个孩子。', 'NS', '麦克马克方式是一种广泛使用的离散化方案，以获得双曲型偏微分方程的数值解决方案。', '莱特从北卡罗来纳州查伯山搬到了纽约市。', '挤喉音是一些口头语言中使用的一种软颚音 国际音标中代表该发音的符号。', '欧洲业务归至玉宝旗下，亚洲业务被香港企业家王永平收购，现归属宝光实业。', '早期咨询委员会成员包括阿利斯泰尔·库克、索尔·贝洛、沃尔特·克朗凯特、诺曼·卡森斯、戈尔·维达尔、诺曼·波德霍雷茨。', '佩特克尔湖国家公园是位于芬兰北卡累利阿的伊洛曼齐的国家公园。', '6 月 13 日，他们还在专辑《恶习》中发行第 5 首曲目，作为该专辑的第二首单曲。', '斯托克城足球俱乐部击败谢菲尔德周三足球俱乐部和哈德斯菲尔德足球俱乐部，后来在第四轮败给彼得伯勒联足球俱乐部。 ...
# ['例外情况发生于 2005 年末至 2009 年期间，当时他效力于瑞典的卡斯塔德联队、塞尔维亚的查查克足球俱乐部和俄罗斯的格罗兹尼艾卡马特足球俱乐部。\n', 'Leurda 河是罗马尼亚境内 Tabaci 河的一条支流。\n', '1993 年，他为 A 级球队波特兰海狗队和 AA 级球队凯恩县美洲狮队效力。\n', '温那斯基是 ACM、IEEE、Phi Beta Kappa 和 Sigma Xi 的成员。\n', '1938 年，他成为英埃苏丹政府的人类学家，并与努巴一起从事野外工作。\n', '黑亚当出现在 2008 年末至 2009 年初出版的前四期《比利·贝特森》中。\n', '利用太阳能满足此项要求的方法是在常规动力飞机上使用太阳能板。\n', '作为持续进行的调查的一部分，警察还询问了歌手 Rimi Tomy 和演员 Kavya Madhavan，二人都是西迪基和他的妻子迪利普的好友。\n', '它们被毫无音色的现场播放的音乐覆盖，并且由模糊不清、几乎故意稀疏的管弦乐声音构成。\n', '霍利 霍利在音乐上受到艾尔顿·约翰的影响。\n', '该队在第二天（2 月 19 日）晚上的同一场比赛中应对变化。\n', '纳舒厄白银骑士团队加入了夏季大学联盟，是本市的现役球队。\n', '"Fall Beil" 于 1949 年最后一次在西德使用并于 1966 年在东德使用。\n', '这条运河是比利时（确切来说是欧洲）最古老的通航运河之一。\n', '他于 2009 年搬回费城，现居住在纽约市。\n', '1954 年 6 月 30 日，他因胃癌于纽约市病逝。而林恩·瑞格斯纪念馆则位于俄克拉荷马州克莱摩尔。\n', 'Stipsits 出生于科尔新堡，并在维也纳施塔莫斯多夫度过了他的童年。\n', '凯塔王朝在 12 世纪至 17 世纪统治了马里，在帝国成立前和帝国成立后都统治了。\n', '《Angel Eyes》是 1946 年的一首由 Earl Brent 作曲 Matt Dennis 作词的流行歌曲。\n', '音乐由希亚姆编写，歌词由斯列库伯兰·坦皮和 Sathyan Anthikkad 创作。\n', '该影片在商业上取得巨大成功，也是塞尔乔·索利马政治元素较多的电影之一，但不如该导演早期的意大利式西部片成功。\n', '卡比尔请求萨利卡向他透露结束兰维尔的游戏的计划。\n', '团队回应了在第二年 2 月的晚上进行的同一场比赛中的变化。\n', '1805 年 5 月，罗伯特·拉姆齐中尉将她派往北海，约翰·盖奇中尉于 1806 年接替了他。\n', '艾玛·汤森是大卫·戈德温在 DGA Associates 的代表。\n', 'Nashua Silver Knights 参加了本届夏季联赛，是该市的大学球队。\n', '268 号宾夕法尼亚大道从帕克以南的大桥西端向北延伸至埃姆伦顿。\n', '这在英国很罕见，但在欧洲，至少对于大型机车来说，它们相对常见。\n', '他于 1965 年 12 月 21 日出生于马里兰州奥克森山，并在康涅狄格州纽黑文上高中。\n', '共有 28 名美国受害人遇害，而越南南方民族解放阵线遇害人数为 345 人，估计另有 192 人死亡。\n', '在 CA，特许会计师的职称（斯里兰卡斯里兰卡）仅限斯里兰卡特许会计师协会会员使用。\n', '在 3 月 14 日收购 E-Plus 的剩余部分后，Simyo 属于荷兰电信集团 KPN。\n', '罗伯特·怀特和乔舒亚·索尔·齐默曼在旁协助担任汉普夏郡大法官法庭专员的库金德尔。\n', '福音派、清教派和新教派的运动兴起期间经常有人表达这种观点。\n', '在 1973 年至 1974 年的欧足联欧洲联赛上，费耶诺德鹿特丹队以 4 比 2 的总比分战胜了托特纳姆热刺队。\n', '塔尔福尔德·伊利是克拉布·鲁滨逊的孙子，后者是约翰·陶威尔·拉特早年的一位朋友。\n', '他的父亲在他年少时去世了，而他的母亲凯瑟琳·A·费根于 1842 年嫁给塞缪尔·亚当斯， 后者在两年后成为阿肯色州州长。\n', '他们还于 6 月 13 日发行了专辑《Vices》的第二首歌曲，作为该专辑的第五首单曲。\n', '1888 年，悉尼水务局从市议会那里接管了悉尼供水事务。\n', 'Cai Mao 也有一个儿子，他叫 Cai Feng。\n', '它的叶子沿着树枝交替排列，呈长矛状、卵状或几乎呈圆形，而且有长茎。\n', '这扩大了罗德岛和马萨诸塞省之间的冲突地区。\n', '斯劳中学是一所位于白金汉郡斯劳（现在为伯克郡）的女子精英学校。\n', '它距离奥格特拉德和克里夫登不远，位于康尼马拉前往科里布湖方向的 N59 号公路上的。\n', '虽然排除非洲球员并非明文规定，但是自 1933 年以来国家橄榄球联盟中没有任何非洲裔美国球员上场踢球。\n', '在穆阿威亚逝世后，阿里掌权并建立王朝。\n', '1994 年，罗德里戈·里奥离开乐队单飞，由卡洛斯·玛利亚·特林达德（键盘合成器）替代。\n', '卡特尔在 1933 年写道，在北欧的所有人种中，“欧洲人种的智力发育水平最高，性情最为平稳”。\n', '落蒺山冷杉通常被称为北美西部枞树或落基山冷杉，是一种亚高山冷杉。\n', 'American Motors 仅以有限帮助的形式提供技术支持。\n', '休斯顿主楼 (HMB) 之前称为慎行大厦，是位于得克萨斯州休斯顿的得克萨斯医学中心的一栋摩天大楼。\n', '1954 年回到苏里南后，他在帕拉马里博定居并成为了一名律师。\n', 'Aerosucre 航班 4544 的坠毁是 Aerosucre 的第二起飞行事故，第一起是 2006 年 11 月 18 日另一架波音 727 的坠毁。\n', '《东海岸》这一集在新斯科舍省现场拍摄，包括卡伯特公路沿路的佩姬湾与布雷顿角高地。\n', '调节鹿群数量的另一条途径是控制出生率。\n', '这首诗被保存在四本当代手稿中，其中一本是残本：\n', "乐队'' Air ``、Howie B、Mars IV、 Les Négresses Vertes 和 FFF 以及曼纽·潮也参与了这张专辑。\n", '胡达萨河是罗马尼亚布拉杜河的支流。\n', '虽然排除黑人球员并非明文规定，但是自 1933 年以来没有任何非洲裔美国人在国家橄榄球联盟中上场踢过球。\n', '他的父亲帕特里克·伯恩是都柏林的代表、下议院议员和市长大人，另一位哥哥阿尔菲·伯恩也是下议院议员。\n', '第二季比第一季更受评论家的喜爱。\n', '范伍德位于第 22 国会选区，是新泽西州第 12 州立法选区的一部分。\n', '贝湖位于流入圣克鲁斯东部的圣克鲁斯河河畔。\n', '文森门站位于巴黎第 12 区的东北角与第 20 区的东南角的交汇处。\n', '2011 年 3 月 5 日，MTV Hive 发布了一条关于蕾哈娜的流媒体链接，她在表演安妮·罗西的《粗鲁男孩》。\n', '公元前 284 年，齐王与赵王在西周会晤，组成联盟对抗西国。\n', '唐朝的陈州行政区现属于河南的辖区，位于周口东部：\n', '“Pure”仅意为“非常”，而“Belter”或“Belta”意为“好”或“大”。\n', '“2”1806 年 8 月 29 日，本杰明·霍夫与伊丽莎白·科尔结婚，由杰斐逊县治安法官史蒂芬·福特证婚。\n', '1846 年，该物种作为约翰·格奥尔格·克里斯蒂安·莱曼的成果 “Irideae Plantae Preissianae” 的一部分由史蒂芬·恩德利希尔首次正式描述。\n', '1912 年，在来自阿姆劳蒂和贝拉尔中部省份的拉奥·巴哈杜尔·拉古纳特·那拉西纳·马霍尔卡尔的主持下，印度国民大会党在班基波举行了第 27 届会议。\n', '最常用的纺织用动物纤维是从绵羊身上收割下来的羊毛。厚羊毛和腈纶纱经常被用于手工编织和编织爱好当中。\n', 'Tipico Co. Ltd 和 Tipico Casino Ltd 成立于 2004 年，是马耳他金融服务局商业登记处的国际贸易公司。\n', '它位于康尼马拉通往科里布湖方向的 N59 号公路上的奥格特拉德和克里夫登附近。\n', '2006 年 9 月 14 日，华盛顿奇才队签下了朗。2017 年 7 月，朗被奇才队裁掉。\n', '这首单曲于 2012 年 10 月 12 日在意大利送到电台播放并于 2012 年 12 月 3 日全球发行。\n', '在服务完毕后，洛克哈特住在了佛罗里达州，但最近搬到了德克萨斯州。\n', '它是在北美洲被发现的，据记载其在此地从纽芬兰和拉布拉多向西延伸至不列颠哥伦比亚，向北延伸至阿拉斯加州和育空。\n', '这个 randallstown 西区包括 Woodlawn、Milford Mill 和 Baltimore County。\n', '他由戴尔·罗曼斯训练，并由骑师约翰·委拉斯开兹指导参加了人生中最重要的骑马比赛。\n', '在萨凡纳的时候，查尔斯·塞莱斯廷从报纸上得知他年幼的儿子谢尔曼在萨凡纳运动中丧生；而将军从未见过这孩子。\n', '封面由纹章艺术家安德鲁·斯图尔特设计，单曲《Steel Monkey》设计了艺术总监约翰·帕奇的封面。\n', '在计算流体动力学中，MacCormack 方法是一种广泛应用于数值方程双曲型偏微分解的离散格式。\n', '莱特从北卡罗来纳州教堂山搬到纽约。\n', '软颚挤喉音是一些口头语言中使用的一种辅音。国际音标 ...

# %%
corpus_path = ["data/bq_corpus/test.tsv", "data/lcqmc/test.tsv", "data/paws-x-zh/test.tsv"]
for path in corpus_path:
    cls_result = []
    test_pairs = open(path, encoding='utf-8').readlines()    
    
    for i in tqdm(range(len(test_pairs))):
        pair = test_pairs[i].split()

        output=model(torch.tensor([tokenizer.encode(pair[0],pair[1])]))
        if torch.nn.functional.softmax(output.logits,dim=-1)[0][0] > 0.5:
            cls_result.append(1)
        else:
            cls_result.append(0)
        # print(torch.nn.functional.softmax(output.logits,dim=-1)[0][0])
              
    with open('result/' + path.split('/')[1] + '.tsv', 'w') as out_file:
        tsv_writer = csv.writer(out_file, delimiter='\t')
        tsv_writer.writerow(['index', 'prediction'])
        for i in range(len(cls_result)):
            tsv_writer.writerow([str(i), str(cls_result[i])])
# Out:
#   0%|          | 8/10000 [00:04<1:28:45,  1.88it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-b037f21b9167> in <module>()
#       7         pair = test_pairs[i].split()
#       8
# ----> 9         output=model(torch.tensor([tokenizer.encode(pair[0],pair[1])]))
#      10         if torch.nn.functional.softmax(output.logits,dim=-1)[0][0] > 0.5:
#      11             cls_result.append(1)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1552             output_attentions=output_attentions,
#    1553             output_hidden_states=output_hidden_states,
# -> 1554             return_dict=return_dict,
#    1555         )
#    1556
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1004             output_attentions=output_attentions,
#    1005             output_hidden_states=output_hidden_states,
# -> 1006             return_dict=return_dict,
#    1007         )
#    1008         sequence_output = encoder_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     590                     encoder_attention_mask,
#     591                     past_key_value,
# --> 592                     output_attentions,
#     593                 )
#     594
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     512
#     513         layer_output = apply_chunking_to_forward(
# --> 514             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     515         )
#     516         outputs = (layer_output,) + outputs
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#    2926         return torch.cat(output_chunks, dim=chunk_dim)
#    2927
# -> 2928     return forward_fn(*input_tensors)
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in feed_forward_chunk(self, attention_output)
#     524     def feed_forward_chunk(self, attention_output):
#     525         intermediate_output = self.intermediate(attention_output)
# --> 526         layer_output = self.output(intermediate_output, attention_output)
#     527         return layer_output
#     528
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, input_tensor)
#     437
#     438     def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 439         hidden_states = self.dense(hidden_states)
#     440         hidden_states = self.dropout(hidden_states)
#     441         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
